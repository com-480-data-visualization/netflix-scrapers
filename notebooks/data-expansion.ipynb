# %% [markdown]
# ### Expansion of the Netflix dataset with the people's birthplace

# %%
# Imports
import pandas as pd
import numpy as np
import json
import requests
import urllib.parse
from tqdm.auto import tqdm
import threading
import time

tqdm.pandas()

# %%
def load_list_from_json(filename):
    """
    Load list from json file
    :param filename: name of the file
    :return data: data from the json file
    """
    with open(filename, 'r') as f:
        data = json.load(f)
    return data


def save_list_to_json(data, filename):
    """
    Save list to json file
    :param data: data to save
    :param filename: name of the file
    """
    with open(filename, 'w') as f:
        json.dump(data, f)

# %%
country_to_capital_dict = load_list_from_json('../data/country_to_capital_city.json')

# %%
TMBD_API_KEY = 'eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNGE2NTk5ZjMyODRjZjkzOGQ4YzMwMmM1NGY3ZTIyZiIsInN1YiI6IjY2MWZkMzVlYTM5ZDBiMDE0YTU1MGU5ZSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.8um8fPsP5yKxzXYZHZy-5oxv_2EEeAVoX8Rz7J2aUKA'

# %%
NINJA_API_KEY = 'HbDls4BdiWMziHcA9GCC6Q==EwPwuLfohR6FZtGi'

# %%
def retrieve_birthplaces_from_tmdb_api(names, results, thread_num, api_key=TMBD_API_KEY):
    """
    Retrieve birthplaces of people
    :param names: list of names
    :param results: dictionary to store results
    :param thread_num: number of the thread
    """
    places_of_birth = []
    for name in tqdm(names):
        name_url = urllib.parse.quote(name)
        url = f"https://api.themoviedb.org/3/search/person?query={name_url}&include_adult=false&language=en-US&page=1"
        headers = {
            "accept": "application/json",
            "Authorization": f"Bearer {api_key}"
        }
        try:
            response = requests.get(url, headers=headers)
            response_dict = json.loads(response.text)
            person_id = response_dict['results'][0]['id']
            url = f"https://api.themoviedb.org/3/person/{str(person_id)}?language=en-US"
            headers = {
                "accept": "application/json",
                "Authorization": f"Bearer {api_key}"
            }
            response = requests.get(url, headers=headers)
            response_dict = json.loads(response.text)
            places_of_birth.append(response_dict['place_of_birth'])
        except Exception as e:
            print(f"An error occurred for {name}: {str(e)}")
            places_of_birth.append(None)

    results[thread_num] = places_of_birth

# %%
def start_multithreading_birthplaces(func, array_list, num_thread):
    """
    Start multithreading 
    :param func: function to be executed
    :param array_list: list of arrays to be passed to the function
    :param num_thread: number of threads
    :return: list of results
    """
    birthplaces_list = []
    results = {}
    start = time.perf_counter()
    threads = []

    for i in range(num_thread):
        t = threading.Thread(target=func, args=(array_list[i]['name'], results, i))
        t.start()
        threads.append(t)

    for thread in threads:
        thread.join()

    for i in range(num_thread):
        birthplaces_list.extend(results[i])

    finish = time.perf_counter()
    print(f'Finished in {round(finish - start, 2)} second(s)')
    return birthplaces_list

# %%
# Read actual file
df_credits = pd.read_csv('../data/credits.csv')  # person_id, id, name, character, role

# %%
NUM_THREADS = 8
df_credits_splitted = np.array_split(df_credits, NUM_THREADS)
birthplaces = start_multithreading_birthplaces(retrieve_birthplaces_from_tmdb_api, df_credits_splitted, NUM_THREADS)
save_list_to_json(birthplaces, './birthplaces.json')

# %%
birthplaces = load_list_from_json('../data/birthplaces.json')
birthplaces = [birthplace if birthplace != 'None' else None for birthplace in birthplaces]
df_credits['birthplace'] = birthplaces
df_credits.to_csv('data/credits_expanded.csv')

# %% [markdown]
# ### Retrieving latitude and longitude of the birthplaces

# %%
def place_parser(place):
    """
    Parse a string containing a place of birth
    :param place: the place to parse
    :return: city, state, country
    """
    USA_SYNONYMES = ['USA', 'United States', 'United States of America', 'US', 'U.S.A.', 'U.S.A', 'U.S.', 'U.S', 'America', 'United States of America (USA)', 'Estados Unidos']
    
    if place is None:
        return None, None, None
        
    if '-' in place and ',' not in place:
        place_splitted = place.split('-')
    else:
        place_splitted = place.split(',')
    
    if len(place_splitted) == 1:
        try:
            capital_city = country_to_capital_dict[place_splitted[0].strip()]
        except Exception as e:
            print(f"An error occurred in the place_parser: the country {str(e)} is not found !")
            capital_city = None
        return capital_city, None, place_splitted[0].strip()
    elif len(place_splitted) == 2:
        if place_splitted[-1].strip() == 'UK':
            return place_splitted[0].strip(), None, 'GB'
        if place_splitted[-1].strip() in USA_SYNONYMES:
            return place_splitted[0].strip(), None, 'US'
        return place_splitted[0].strip(), None, place_splitted[1].strip()
    elif len(place_splitted) == 3:
        if place_splitted[-1].strip() == 'UK':
            return place_splitted[0].strip(), None, 'GB'
        if place_splitted[-1].strip() in USA_SYNONYMES:
            return place_splitted[0].strip(), place_splitted[1].strip(), 'US'
        return place_splitted[0].strip(), place_splitted[1].strip(), place_splitted[2].strip()
    else:
        if place_splitted[-1].strip() == 'UK':
            return place_splitted[0].strip(), None, 'GB'
        if place_splitted[-1].strip() in USA_SYNONYMES:
            return place_splitted[1].strip(), place_splitted[2].strip(), 'US'
        return place_splitted[1].strip(), place_splitted[2].strip(), place_splitted[3].strip()

# %%
def retrieve_latlong_from_ninja_api(places, results, errors, lock_res, lock_error, api_key=NINJA_API_KEY):
    """
    Retrieve latitude and longitude of a place
    :param places: list of place names
    :param results: dictionary to store results (conccurent access)
    :param errors: list to store errors (conccurent access)
    :param lock_res: lock for the results
    :param lock_error: lock for the errors
    """

    def make_api_call(api_url, api_key):
        """
        Make an API call to retrieve the latitude and longitude of a place
        :param api_url: the url of the Ninja API
        :param api_key: the Ninja API key
        """
        while True:
            response = requests.get(api_url, headers={'X-Api-Key': api_key})
            if response.status_code == requests.codes.ok:
                try:
                    city_info = json.loads(response.text)[0]
                    lock_res.acquire()
                    results[place_parsed_string] = (city_info['latitude'], city_info['longitude'])
                    lock_res.release()
                except Exception as e:
                    lock_error.acquire()
                    errors.append(place)
                    lock_error.release()
                    print(f"Error {e}: {place} was not found (was parsed into {place_parsed_string})")
                break
            else:
                print("Error:", response.status_code, response.text, "Retrying in 5 seconds...")
                time.sleep(5) # Wait for 5 seconds before retrying because of API Throttled

    for place in tqdm(places):
        place_parsed = (city, state, country) = place_parser(place)
        if city and country:
            place_parsed_string = ', '.join(place_parsed) if state else ', '.join([city, country])
        else: 
            continue
            
        if place_parsed_string in results:
            continue
        else:
            api_url = f'https://api.api-ninjas.com/v1/geocoding?city={city}&state={state}&country={country}' if state else f'https://api.api-ninjas.com/v1/geocoding?city={city}&country={country}'
            make_api_call(api_url, api_key)

# %%
def start_multithreading_latlong(func, array_list, results, errors, num_thread):
    """
    Start multithreading 
    :param func: function to be executed
    :param array_list: list of arrays to be passed to the function
    :param results: dictionary to store results
    :param errors: list to store errors
    :param num_thread: number of threads
    """
    start = time.perf_counter()
    threads = []
    lock_res = threading.Lock()
    lock_error = threading.Lock()
    for i in range(num_thread):
        t = threading.Thread(target=func, args=(array_list[i], results, errors, lock_res, lock_error))
        t.start()
        threads.append(t)

    for thread in threads:
        thread.join()

    finish = time.perf_counter()
    print(f'Finished in {round(finish - start, 2)} second(s)')

# %%
NUM_THREADS = 4
df = pd.read_csv('../data/credits_expanded.csv')
birthplaces = df["birthplace"].dropna().unique()
print(f'Number of unique birthplaces: {len(birthplaces)}')
birthplaces_splitted = np.array_split(birthplaces, NUM_THREADS)
# Out:
# Number of unique birthplaces: 8309

# %%
results = {}
errors = []
start_multithreading_latlong(retrieve_latlong_from_ninja_api, birthplaces_splitted, results, errors, NUM_THREADS)
save_list_to_json(results, '../data/place_to_latlong.json')
save_list_to_json(errors, '../data/places_not_found.json')
# Out:
#   0%|          | 0/2077 [00:00<?, ?it/s]
#   0%|          | 0/2077 [00:00<?, ?it/s]
#   0%|          | 0/2077 [00:00<?, ?it/s]
#   0%|          | 0/2078 [00:00<?, ?it/s]
# Error list index out of range: South East London - England - UK was not found (was parsed into South East London, GB)
# Error list index out of range: Agouk, Ivory Coast was not found (was parsed into Agouk, Ivory Coast)
# Error list index out of range: Voskresensk, Moscow Oblast, Russian SFSR, USSR [now Russia] was not found (was parsed into Moscow Oblast, Russian SFSR, USSR [now Russia])
# Error list index out of range: County Cork, Ireland was not found (was parsed into County Cork, Ireland)
# Error list index out of range: Shreveport. Louisiana, USA was not found (was parsed into Shreveport. Louisiana, US)
# An error occurred in the place_parser: the country 'America' is not found !
# Error list index out of range: Rabun County, Georgia, USA was not found (was parsed into Rabun County, Georgia, US)
# Error list index out of range: South Carolina, USA was not found (was parsed into South Carolina, US)
# Error list index out of range: Tangiers, Morocco was not found (was parsed into Tangiers, Morocco)
# Error list index out of range: Worblaufen BE, Switzerland was not found (was parsed into Worblaufen BE, Switzerland)
# Error list index out of range: Belfast, Ireland was not found (was parsed into Belfast, Ireland)
# An error occurred in the place_parser: the country 'Paris' is not found !
# Error list index out of range: Minsk, Byelorussian SSR, USSR, [now Belarus] was not found (was parsed into Byelorussian SSR, USSR, [now Belarus])
# An error occurred in the place_parser: the country 'Pingdingshan，He‘nan Province，China' is not found !
# An error occurred in the place_parser: the country 'Shenyang，Liaoning Province，China' is not found !
# An error occurred in the place_parser: the country 'Weihai，Shandong Province，China' is not found !
# An error occurred in the place_parser: the country '中国，河南' is not found !
# An error occurred in the place_parser: the country 'Parma (Italy)' is not found !
# Error list index out of range: Shaxi, Zhonghsan, Guangdong Province, China was not found (was parsed into Zhonghsan, Guangdong Province, China)
# An error occurred in the place_parser: the country '中国北京' is not found !
# An error occurred in the place_parser: the country '中华人民共和国北京市' is not found !
# Error list index out of range: Novosibirsk, Novosibirskaya oblast, RSFSR, USSR was not found (was parsed into Novosibirskaya oblast, RSFSR, USSR)
# Error list index out of range: Makrusha, Krasnoyarskaya oblast, RSFSR, USSR was not found (was parsed into Krasnoyarskaya oblast, RSFSR, USSR)
# Error list index out of range: Severodvinsk, Arkhangelskaya oblast, RSFSR, USSR was not found (was parsed into Arkhangelskaya oblast, RSFSR, USSR)
# An error occurred in the place_parser: the country 'jiayi，taiwan，China' is not found !
# Error list index out of range: Mytischi, RSFSR, USSR was not found (was parsed into Mytischi, RSFSR, USSR)
# An error occurred in the place_parser: the country 'الكويت' is not found !
# Error list index out of range: Riga, Latvian SSR, USSR, [now Latvia] was not found (was parsed into Latvian SSR, USSR, [now Latvia])
# Error list index out of range: Sochi, Krasnodarskiy kray, RSFSR, USSR was not found (was parsed into Krasnodarskiy kray, RSFSR, USSR)
# Error list index out of range: Tainan City, Taiwan was not found (was parsed into Tainan City, Taiwan)
# Error list index out of range: Leningrad, RSFSR, USSR (now St. Petersburg, Russia) was not found (was parsed into RSFSR, USSR (now St. Petersburg, Russia))
# Error list index out of range: Heidleberg, Germany was not found (was parsed into Heidleberg, Germany)
# An error occurred in the place_parser: the country 'Cotabato' is not found !
# An error occurred in the place_parser: the country 'Wuhan，Hubei Province，China' is not found !
# An error occurred in the place_parser: the country 'Mudanjiang，Heilongjiang Province，China' is not found !
# An error occurred in the place_parser: the country 'Suzhou，Jiangsu Province，China' is not found !
# An error occurred in the place_parser: the country 'Tianjin，China' is not found !
# Error list index out of range: Negeri Sembilan, Malaysia was not found (was parsed into Negeri Sembilan, Malaysia)
# Error list index out of range: Gunma, Japan was not found (was parsed into Gunma, Japan)
# An error occurred in the place_parser: the country 'Aceh' is not found !
# An error occurred in the place_parser: the country 'Ivory Coast' is not found !
# An error occurred in the place_parser: the country 'Nedumangad' is not found !
# Error list index out of range: Dumiyatt, Egypt was not found (was parsed into Dumiyatt, Egypt)
# An error occurred in the place_parser: the country 'Tunis' is not found !
# Error list index out of range: Allaippiddi, Sri Lanka was not found (was parsed into Allaippiddi, Sri Lanka)
# An error occurred in the place_parser: the country 'Chifeng，Inner Mongolia，China' is not found !
# Error list index out of range: Musoma Rural District, Tanzania was not found (was parsed into Musoma Rural District, Tanzania)
# An error occurred in the place_parser: the country '泰国' is not found !
# Error list index out of range: Stolp, Pomerania, Germany (now Slupsk, Pomorskie, Poland) was not found (was parsed into Pomerania, Germany (now Slupsk, Pomorskie)
# Error list index out of range: Sonagazi, Bangladesh was not found (was parsed into Sonagazi, Bangladesh)
# An error occurred in the place_parser: the country 'Egyptian' is not found !
# An error occurred in the place_parser: the country 'Sukabumi' is not found !
# Error list index out of range: Shihlin, Taipei, Taiwan was not found (was parsed into Shihlin, Taipei, Taiwan)
# Error list index out of range: Taipei City, Taipei, Taiwan was not found (was parsed into Taipei City, Taipei, Taiwan)
# Error list index out of range: Ilaiyangudi, Madras Presidency, British India was not found (was parsed into Ilaiyangudi, Madras Presidency, British India)
# An error occurred in the place_parser: the country 'Wonosobo' is not found !
# Error list index out of range: Lazovsk, USSR (Sinjereya, Moldavia) was not found (was parsed into Lazovsk, USSR (Sinjereya, Moldavia))
# An error occurred in the place_parser: the country 'Garbagnate Milanese' is not found !
# Error list index out of range: Maebashi City, Gunma Prefecture, Japan was not found (was parsed into Maebashi City, Gunma Prefecture, Japan)
# An error occurred in the place_parser: the country 'Mysore' is not found !
# An error occurred in the place_parser: the country 'Kattenberg' is not found !
# Error list index out of range: Kiev, Ukrainian SSR, USSR, [now Ukraine] was not found (was parsed into Ukrainian SSR, USSR, [now Ukraine])
# An error occurred in the place_parser: the country 'Verona' is not found !
# Error list index out of range: Cittadella (PD), Italy was not found (was parsed into Cittadella (PD), Italy)
# Error list index out of range: Karlstadt am Main, Germany was not found (was parsed into Karlstadt am Main, Germany)
# An error occurred in the place_parser: the country 'Polska' is not found !
# An error occurred in the place_parser: the country 'Magelang' is not found !
# Error list index out of range: County Meath, Republic of Ireland was not found (was parsed into County Meath, Republic of Ireland)
# Error list index out of range: États-Unis was not found (was parsed into États, Unis)
# Error list index out of range: Quebec City, Quebec, Canada was not found (was parsed into Quebec City, Quebec, Canada)
# An error occurred in the place_parser: the country 'Québec' is not found !
# Error list index out of range:  Quebec City, Quebec, Canada  was not found (was parsed into Quebec City, Quebec, Canada)
# An error occurred in the place_parser: the country 'Qingdao，Shandong，China' is not found !
# Error list index out of range: Évreax, France was not found (was parsed into Évreax, France)
# Error list index out of range: Toulouse, France, EU was not found (was parsed into Toulouse, France, EU)
# An error occurred in the place_parser: the country 'Nador' is not found !
# Error list index out of range: Ashigarakami, Kanagawa, Japan was not found (was parsed into Ashigarakami, Kanagawa, Japan)
# Error list index out of range: Denby Dale, West Yorkshire,  England, United Kingdom was not found (was parsed into West Yorkshire, England, United Kingdom)
# An error occurred in the place_parser: the country '北京，中国' is not found !
# Error list index out of range: Baltimora, Maryland, Stati Uniti was not found (was parsed into Baltimora, Maryland, Stati Uniti)
# Error list index out of range: Amsterdam, Netherlands, EU was not found (was parsed into Amsterdam, Netherlands, EU)
# Error list index out of range: Madhuranthakam, Tamil Nadu, India was not found (was parsed into Madhuranthakam, Tamil Nadu, India)
# Error list index out of range: Ross County, Ohio, United States was not found (was parsed into Ross County, Ohio, US)
# An error occurred in the place_parser: the country 'Biên Hòa' is not found !
# Error list index out of range: Brooklyn, NY was not found (was parsed into Brooklyn, NY)
# Error list index out of range: Prefettura di Saitama, Japan was not found (was parsed into Prefettura di Saitama, Japan)
# Error list index out of range: Dubno k. Bielska Podlaskiego, Rzesza Niemiecka (now. Poland) was not found (was parsed into Dubno k. Bielska Podlaskiego, Rzesza Niemiecka (now. Poland))
# Error list index out of range: Ikwuano Umuahia, Abia State, Nigeria was not found (was parsed into Ikwuano Umuahia, Abia State, Nigeria)
# An error occurred in the place_parser: the country '中国河南三门峡' is not found !
# An error occurred in the place_parser: the country 'Tonghua，Jilin Province，China' is not found !
# Finished in 2931.99 second(s)
