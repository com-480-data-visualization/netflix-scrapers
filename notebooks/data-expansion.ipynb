# %% [markdown]
# ### Expansion of the Netflix dataset with the people's birthplace

# %%
# Imports
import pandas as pd
import numpy as np
import json
import requests
import urllib.parse
from tqdm.auto import tqdm
import threading
import time
import gpt_wrapper
from gpt_wrapper.chat import Chat
import os
import ast

tqdm.pandas()

# %%
def load_list_from_json(filename):
    """
    Load list from json file
    :param filename: name of the file
    :return data: data from the json file
    """
    with open(filename, 'r') as f:
        data = json.load(f)
    return data


def save_list_to_json(data, filename):
    """
    Save list to json file
    :param data: data to save
    :param filename: name of the file
    """
    with open(filename, 'w') as f:
        json.dump(data, f)

# %%
country_to_capital_dict = load_list_from_json('../data/country_to_capital_city.json')

# %%
TMBD_API_KEY = 'None'

# %%
NINJA_API_KEY = 'None'

# %%
def retrieve_birthplaces_from_tmdb_api(names, results, thread_num, api_key=TMBD_API_KEY):
    """
    Retrieve birthplaces of people
    :param names: list of names
    :param results: dictionary to store results
    :param thread_num: number of the thread
    """
    places_of_birth = []
    for name in tqdm(names):
        name_url = urllib.parse.quote(name)
        url = f"https://api.themoviedb.org/3/search/person?query={name_url}&include_adult=false&language=en-US&page=1"
        headers = {
            "accept": "application/json",
            "Authorization": f"Bearer {api_key}"
        }
        try:
            response = requests.get(url, headers=headers)
            response_dict = json.loads(response.text)
            person_id = response_dict['results'][0]['id']
            url = f"https://api.themoviedb.org/3/person/{str(person_id)}?language=en-US"
            headers = {
                "accept": "application/json",
                "Authorization": f"Bearer {api_key}"
            }
            response = requests.get(url, headers=headers)
            response_dict = json.loads(response.text)
            places_of_birth.append(response_dict['place_of_birth'])
        except Exception as e:
            print(f"An error occurred for {name}: {str(e)}")
            places_of_birth.append(None)

    results[thread_num] = places_of_birth

# %%
def start_multithreading_birthplaces(func, array_list, num_thread):
    """
    Start multithreading 
    :param func: function to be executed
    :param array_list: list of arrays to be passed to the function
    :param num_thread: number of threads
    :return: list of results
    """
    birthplaces_list = []
    results = {}
    start = time.perf_counter()
    threads = []

    for i in range(num_thread):
        t = threading.Thread(target=func, args=(array_list[i]['name'], results, i))
        t.start()
        threads.append(t)

    for thread in threads:
        thread.join()

    for i in range(num_thread):
        birthplaces_list.extend(results[i])

    finish = time.perf_counter()
    print(f'Finished in {round(finish - start, 2)} second(s)')
    return birthplaces_list

# %%
# Read actual file
df_credits = pd.read_csv('../data/credits.csv')  # person_id, id, name, character, role

# %%
NUM_THREADS = 8
df_credits_splitted = np.array_split(df_credits, NUM_THREADS)
birthplaces = start_multithreading_birthplaces(retrieve_birthplaces_from_tmdb_api, df_credits_splitted, NUM_THREADS)
save_list_to_json(birthplaces, './birthplaces.json')

# %%
birthplaces = load_list_from_json('../data/birthplaces.json')
birthplaces = [birthplace if birthplace != 'None' else None for birthplace in birthplaces]
df_credits['birthplace'] = birthplaces
df_credits.to_csv('data/credits_expanded.csv')

# %% [markdown]
# ### Retrieving latitude and longitude of the birthplaces

# %%
def place_parser(place):
    """
    Parse a string containing a place of birth
    :param place: the place to parse
    :return: city, state, country
    """
    USA_SYNONYMES = ['USA', 'United States', 'United States of America', 'US', 'U.S.A.', 'U.S.A', 'U.S.', 'U.S',
                     'America', 'United States of America (USA)', 'Estados Unidos']

    if place is None:
        return None, None, None

    if '-' in place and ',' not in place:
        place_splitted = place.split('-')
    else:
        place_splitted = place.split(',')

    if len(place_splitted) == 1:
        try:
            country = place_splitted[0].strip()
            if country in USA_SYNONYMES: country = 'United States of America'
            capital_city = country_to_capital_dict[country]
        except Exception as e:
            print(f"An error occurred in the place_parser: the country {str(e)} is not found !")
            capital_city = None
        return capital_city, None, place_splitted[0].strip()
    elif len(place_splitted) == 2:
        if place_splitted[-1].strip() == 'UK':
            return place_splitted[0].strip(), None, 'GB'
        if place_splitted[-1].strip() in USA_SYNONYMES:
            return place_splitted[0].strip(), None, 'US'
        return place_splitted[0].strip(), None, place_splitted[1].strip()
    elif len(place_splitted) == 3:
        if place_splitted[-1].strip() == 'UK':
            return place_splitted[0].strip(), None, 'GB'
        if place_splitted[-1].strip() in USA_SYNONYMES:
            return place_splitted[0].strip(), place_splitted[1].strip(), 'US'
        return place_splitted[0].strip(), place_splitted[1].strip(), place_splitted[2].strip()
    else:
        if place_splitted[-1].strip() == 'UK':
            return place_splitted[0].strip(), None, 'GB'
        if place_splitted[-1].strip() in USA_SYNONYMES:
            return place_splitted[1].strip(), place_splitted[2].strip(), 'US'
        return place_splitted[1].strip(), place_splitted[2].strip(), place_splitted[3].strip()

# %%
def retrieve_latlong_from_ninja_api(places, results, errors, lock_res, lock_error, api_key=NINJA_API_KEY):
    """
    Retrieve latitude and longitude of a place
    :param places: list of place names
    :param results: dictionary to store results (conccurent access)
    :param errors: list to store errors (conccurent access)
    :param lock_res: lock for the results
    :param lock_error: lock for the errors
    """

    def make_api_call(api_url, api_key):
        """
        Make an API call to retrieve the latitude and longitude of a place
        :param api_url: the url of the Ninja API
        :param api_key: the Ninja API key
        """
        while True:
            response = requests.get(api_url, headers={'X-Api-Key': api_key})
            if response.status_code == requests.codes.ok:
                try:
                    city_info = json.loads(response.text)[0]
                    lock_res.acquire()
                    results[place_parsed_string] = (city_info['latitude'], city_info['longitude'])
                    lock_res.release()
                except Exception as e:
                    lock_error.acquire()
                    errors.append(place)
                    lock_error.release()
                    print(f"Error {e}: {place} was not found (was parsed into {place_parsed_string})")
                break
            else:
                print("Error:", response.status_code, response.text, "Retrying in 5 seconds...")
                time.sleep(5)  # Wait for 5 seconds before retrying because of API Throttled

    for place in tqdm(places):
        place_parsed = (city, state, country) = place_parser(place)
        if city and country:
            place_parsed_string = ', '.join(place_parsed) if state else ', '.join([city, country])
        else:
            continue

        if place_parsed_string in results:
            continue
        else:
            api_url = f'https://api.api-ninjas.com/v1/geocoding?city={city}&state={state}&country={country}' if state else f'https://api.api-ninjas.com/v1/geocoding?city={city}&country={country}'
            make_api_call(api_url, api_key)

# %%
def start_multithreading_latlong(func, array_list, results, errors, num_thread):
    """
    Start multithreading 
    :param func: function to be executed
    :param array_list: list of arrays to be passed to the function
    :param results: dictionary to store results
    :param errors: list to store errors
    :param num_thread: number of threads
    """
    start = time.perf_counter()
    threads = []
    lock_res = threading.Lock()
    lock_error = threading.Lock()
    for i in range(num_thread):
        t = threading.Thread(target=func, args=(array_list[i], results, errors, lock_res, lock_error))
        t.start()
        threads.append(t)

    for thread in threads:
        thread.join()

    finish = time.perf_counter()
    print(f'Finished in {round(finish - start, 2)} second(s)')

# %%
NUM_THREADS = 4
df = pd.read_csv('../data/credits_expanded.csv')
birthplaces = df["birthplace"].dropna().unique()
print(f'Number of unique birthplaces: {len(birthplaces)}')
birthplaces_splitted = np.array_split(birthplaces, NUM_THREADS)
# Out:
# Number of unique birthplaces: 8309

# %%
results = {}
errors = []
start_multithreading_latlong(retrieve_latlong_from_ninja_api, birthplaces_splitted, results, errors, NUM_THREADS)
save_list_to_json(results, '../data/place_to_latlong.json')
save_list_to_json(errors, '../data/places_not_found.json')

# %% [markdown]
# ### RETRIEVE THE COUNTRY OF THE BIRTHPLACE

# %%
gpt_wrapper.api_base = "http://mnlp-backend-938795011.eu-central-1.elb.amazonaws.com"
gpt_wrapper.api_key = "None"

# %%
def gpt_retrieve(list, counts, thread_num, chuck=20):
    chat = None
    list_split = np.array_split(list, chuck)
    count = counts[thread_num]
    for i, places in tqdm(enumerate(list_split), total=len(list_split)):
        # Skip already processed places
        if i < count:
            continue

        string_of_places = ""
        for place in places:
            if not place:
                string_of_places += 'None' + '§'
            else:
                string_of_places += str(place) + '§'
        string_of_places = string_of_places.rstrip("§")

        new_chat = True
        error = ""
        
        while True:
            content = error + string_of_places
            error = ""
            try:
                if new_chat:
                    chat = Chat.create("Chat Data Viz" + ' ' + str(thread_num) + ' ' + str(i))
                    message = chat.ask(content=content,
                                       instruction="Given a list of places separated by '§', You'll return only a list of dict where each place is processed in the format: (city, state, country, country in ISO 3166-1 alpha-2 format, (latitude, longitude)) with 6 decimal precision for numbers. Put the floats into strings. All names will be in English. For example: {\"city\": \"Paris\", \"state\": \"Île-de-France\", \"country\": \"France\", \"country_code\": \"FR\", \"coordinates\": [\"48.864716\", \"2.349014\"]}. Provide data in json format, as if you did a json.dump with the list, without the ```json ... ``` and with ',' delimiters. The response must have EXACTLY as many elements as the input list. If the place is 'nan' return 'None'. If a particular place appears consecutively multiple times, you should return it the same number of times it occurs in the sequence. If a country doesn't exist anymore, put today's equivalence (ex: Russia instead of USSR).")
                    new_chat = False
                else:
                    message = chat.ask(content=content)
                
                response = json.loads(str(message))

                if len(response) == len(places):
                    path = f'../data/gpt_data_thread_{thread_num}_count_{count}.json'
                    count += 1
                    new_path = f'../data/gpt_data_thread_{thread_num}_count_{count}.json'
                    data = load_list_from_json(path)
                    data.extend(response)
                    os.remove(path)
                    save_list_to_json(data, new_path)
                    break
                else:
                    error = f'You made an error in the previous generation: wrong generated length {len(response)} instead of {len(places)}. Do it again: \n\n\n'
                    print(f'Error: wrong generated length {len(response)} instead of {len(places)} :(.  Retrying...')
                    print(f'Input message: {string_of_places}')
                    print(f'Generated message: {response}')

            except Exception as e:
                if 'context_length_exceeded' in str(e):
                    new_chat = True
                elif "Expecting \',\' delimiter" in str(e) or "Expecting value" in str(e):
                    error = f'You made an error in the previous generation: {str(e)}. Do it again with the same list WITHOUT the fucking error: \n\n\n'
                    print(f"An error occurred: {str(e)}")
                    print(places)
                    print(' what you gave me: ' + str(message) + '\n\n')
                else:
                    print(f"An error occurred: {str(e)}")
                    print('Retrying in 15 seconds...')
                    time.sleep(15)

# %%
def start_multithreading_gpt(func, array_list, counts, num_thread):
    """
    Start multithreading 
    :param func: function to be executed
    :param array_list: list of arrays to be passed to the function
    :param num_thread: number of threads
    :return results: dictionary to store results
    """
    start = time.perf_counter()
    threads = []

    for i in range(num_thread):
        t = threading.Thread(target=func, args=(array_list[i], counts, i))
        t.start()
        threads.append(t)

    for thread in threads:
        thread.join()

    finish = time.perf_counter()
    print(f'Finished in {round(finish - start, 2)} second(s)')

# %%
Chat.budget()
# Out:
# {'limit': 10000000, 'usage': 3607323}

# %%
NUM_THREADS = 4
places = load_list_from_json('../data/places_not_found.json')
places_split = np.array_split(places, NUM_THREADS)
# Out:
# 638

# %%
#for i in range(4):
#    path = f'../data/gpt_data_thread_{i}_count_0.json'
#    save_list_to_json([], path)

# %%
counts = [8, 20, 20, 20] # Number of already processed places, useful in case of interruption
start_multithreading_gpt(gpt_retrieve, places_split, counts, NUM_THREADS)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 counts = [8, 20, 20, 20] # Number of already processed places, useful in case of interruption
# ----> 2 start_multithreading_gpt(gpt_retrieve, places_split, counts, NUM_THREADS)
#
# Cell In[27], line 18, in start_multithreading_gpt(func, array_list, counts, num_thread)
#      15     threads.append(t)
#      17 for thread in threads:
# ---> 18     thread.join()
#      20 finish = time.perf_counter()
#      21 print(f'Finished in {round(finish - start, 2)} second(s)')
#
# File ~/anaconda3/envs/dataviz/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/anaconda3/envs/dataviz/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
# Fetch the threads' result and concatenate them
list_gpt = []
for i in range(NUM_THREADS):
    data = load_list_from_json(f'../data/gpt_data_thread_{i}_count_{20}.json')
    list_gpt.extend(data)
    
dict = {}
for j in range(len(places)):
    dict[places[j]] = list_gpt[j]
    
save_list_to_json(dict, '../data/places_not_found_to_latlong.json')

# %% [markdown]
# ### Construct the new data frame summarizing all data

# %%
place_to_latlong = load_list_from_json('../data/place_to_latlong.json')
place_not_found_to_latlong = load_list_from_json('../data/place_not_found_to_latlong.json')

df_credits_expanded = pd.read_csv('../data/credits_expanded.csv')
df_credits_expanded
# Out:
#        Unnamed: 0  person_id         id                name  \
# 0               0       3748    tm84618      Robert De Niro
# 1               1      14658    tm84618        Jodie Foster
# 2               2       7064    tm84618       Albert Brooks
# 3               3       3739    tm84618       Harvey Keitel
# 4               4      48933    tm84618     Cybill Shepherd
# ...           ...        ...        ...                 ...
# 77796       77796     736339  tm1059008    Adelaida Buscato
# 77797       77797     399499  tm1059008  Luz Stella Luengas
# 77798       77798     373198  tm1059008         Inés Prieto
# 77799       77799     378132  tm1059008        Isabel Gaona
# 77800       77800    1950416  tm1059008      Julian Gaviria
#
#                      character      role  \
# 0                Travis Bickle     ACTOR
# 1                Iris Steensma     ACTOR
# 2                          Tom     ACTOR
# 3      Matthew 'Sport' Higgins     ACTOR
# 4                        Betsy     ACTOR
# ...                        ...       ...
# 77796                María Paz     ACTOR
# 77797             Karen Bayona     ACTOR
# 77798                    Fanny     ACTOR
# 77799                   Cacica     ACTOR
# 77800                      NaN  DIRECTOR
#
#                                             birthplace
# 0      Greenwich Village, New York City, New York, USA
# 1                         Los Angeles, California, USA
# 2                       Beverly Hills, California, USA
# 3               Brooklyn, New York City, New York, USA
# 4                              Memphis, Tennessee, USA
# ...                                                ...
# 77796                                              NaN
# 77797                    Medellin, Antioquia, Colombia
# 77798                                              NaN
# 77799                                              NaN
# 77800                                              NaN
#
# [77801 rows x 7 columns]

# %%
# Append ISO to place_to_latlong
data = load_list_from_json('../data/place_to_latlong.json')
country_to_ISO = load_list_from_json('../data/country_to_ISO.json')
new_data = {}

def append_iso(string_place):
    string_parsed = string_place.split(',')
    country = string_parsed[-1].strip()
        
    new_k = ""
    i = 0
    
    if country == 'US':
        while string_parsed[i].strip() != 'US':
            new_k += string_parsed[i].strip() + ', '
            i += 1
        new_k += 'United States, US'
    elif country == 'GB':
        while string_parsed[i].strip() != 'GB':
            new_k += string_parsed[i].strip() + ', '
            i += 1
        new_k += 'United Kingdom, GB'
    
    else:
        iso = country_to_ISO.get(country, "None")
        new_k = string_place + ', ' + iso
    
    return new_k


for k, v in data.items():
    new_k = append_iso(k)
    new_data[new_k] = v
    
    
save_list_to_json(new_data, '../data/new_place_to_latlong.json')

# %%
df_credits = pd.read_csv('../data/credits.csv')
place_not_found_to_latlong = load_list_from_json('../data/place_not_found_to_latlong.json')
new_place_to_latlong = load_list_from_json('../data/new_place_to_latlong.json')

cities = []
states = []
countries = []
isos = []
latlongs = []

def decode_latlong(latlong):
    if not latlong or latlong == "None" or (latlong[0] == "None" and latlong[1] == "None"): return None
    return float(latlong[0]), float(latlong[1])

def get_place_info(place):
    if not place:
        return None, None, None, None, None
    
    if place in place_not_found_to_latlong:
        infos = place_not_found_to_latlong[place]
        city = infos.get('city', None)
        state = infos.get('state', None)
        country = infos.get('country', None)
        iso = infos.get('country_code', None)
        latlong = decode_latlong(infos.get('coordinates'))
    
    else:
        place = city, state, country = place_parser(place)
        if not country:
            return None, None, None, None, None
        if not state:
            place = (city, country)
        if not city:
            place = country
        place = append_iso(', '.join(place))
        country = place.split(', ')[-2]
        iso = place.split(', ')[-1]
        if place in new_place_to_latlong:
            latlong = decode_latlong(new_place_to_latlong[place])
        else:
            latlong = None
            
    return city, state, country, iso, latlong


# Iterate over each row in the DataFrame
for index, row in df_credits_expanded.iterrows():
    if pd.isna(df_credits_expanded.at[index, 'birthplace']):
        cities.append(None)
        states.append(None)
        countries.append(None)
        isos.append(None)
        latlongs.append(None)
        continue
    
    place = row['birthplace']
    place_info = get_place_info(place)
    cities.append(place_info[0])
    states.append(place_info[1])
    countries.append(place_info[2])
    isos.append(place_info[3])
    latlongs.append(place_info[4])
    
df_credits['city'] = cities
df_credits['state'] = states
df_credits['country'] = countries
df_credits['iso'] = isos
df_credits['latlong'] = latlongs

df_credits.to_csv('../data/new_credits.csv')
# Out:
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Peshawar' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Peshawar' is not found !
# An error occurred in the place_parser: the country 'New York City' is not found !
# An error occurred in the place_parser: the country 'Como (Italy)' is not found !
# An error occurred in the place_parser: the country 'USSR [now Russia]' is not found !
# An error occurred in the place_parser: the country '日本，静冈县，磐田市' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Prayagraj' is not found !
# An error occurred in the place_parser: the country 'Delhi' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Arizona' is not found !
# An error occurred in the place_parser: the country '日本神奈川县' is not found !
# An error occurred in the place_parser: the country 'Puerto Rico' is not found !
# An error occurred in the place_parser: the country 'Palestine' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Gran Bretagna' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Wales' is not found !
# An error occurred in the place_parser: the country 'Pennsylvania' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Francia' is not found !
# An error occurred in the place_parser: the country 'Puerto Rico' is not found !
# An error occurred in the place_parser: the country 'Giamaica' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Parma (Italy)' is not found !
# An error occurred in the place_parser: the country 'Pennsylvania' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country '高雄，中国台湾' is not found !
# An error occurred in the place_parser: the country '日本神奈川县' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country '日本神奈川县' is not found !
# An error occurred in the place_parser: the country 'South Korean' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Barcelona' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country '日本神奈川县' is not found !
# An error occurred in the place_parser: the country 'Taipei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'لبنان' is not found !
# An error occurred in the place_parser: the country 'لبنان' is not found !
# An error occurred in the place_parser: the country 'لبنان' is not found !
# An error occurred in the place_parser: the country 'لبنان' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Shanghai，China' is not found !
# An error occurred in the place_parser: the country 'Bursa' is not found !
# An error occurred in the place_parser: the country 'Delhi' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong，China' is not found !
# An error occurred in the place_parser: the country "Xi'an，Shanxi Province，China" is not found !
# An error occurred in the place_parser: the country 'Yichun，Heilongjiang Province，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'British India' is not found !
# An error occurred in the place_parser: the country 'Taipei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'لبنان' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Beit Jala Palestinian' is not found !
# An error occurred in the place_parser: the country 'Tirumangalam' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Phillipines' is not found !
# An error occurred in the place_parser: the country 'Europe' is not found !
# An error occurred in the place_parser: the country 'San Jose' is not found !
# An error occurred in the place_parser: the country 'Czechoslovakia' is not found !
# An error occurred in the place_parser: the country 'Czechoslovakia' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country '中国香港特别行政区' is not found !
# An error occurred in the place_parser: the country 'U.K.' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'Oslo' is not found !
# An error occurred in the place_parser: the country 'Pennsylvania' is not found !
# An error occurred in the place_parser: the country 'Taipei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Shanghai，China' is not found !
# An error occurred in the place_parser: the country 'Prayagraj' is not found !
# An error occurred in the place_parser: the country 'Rhodesia' is not found !
# An error occurred in the place_parser: the country 'Chengdu，Sichuan Province，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Tieling，Liaoning Province，China' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Baotou，Inner Mongolia，China' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Peshawar' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Bogor' is not found !
# An error occurred in the place_parser: the country 'Gadarwara' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'Great Britain Scotland' is not found !
# An error occurred in the place_parser: the country 'South Vietnam' is not found !
# An error occurred in the place_parser: the country 'Arizona' is not found !
# An error occurred in the place_parser: the country 'Sudafrica' is not found !
# An error occurred in the place_parser: the country 'American Samoa' is not found !
# An error occurred in the place_parser: the country 'American Samoa' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'California' is not found !
# An error occurred in the place_parser: the country 'Scotland' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Londra' is not found !
# An error occurred in the place_parser: the country 'Northern Ireland' is not found !
# An error occurred in the place_parser: the country 'Bursa' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Phillipines' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Gadarwara' is not found !
# An error occurred in the place_parser: the country 'Prayagraj' is not found !
# An error occurred in the place_parser: the country 'Langfang，Hebei Province，China' is not found !
# An error occurred in the place_parser: the country "Qiqiha'er，Heilongjiang Province" is not found !
# An error occurred in the place_parser: the country 'Xianning，Hubei Province，China' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country '中国湖南省长沙市' is not found !
# An error occurred in the place_parser: the country '香港' is not found !
# An error occurred in the place_parser: the country 'Hong Kong，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Taibei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Sudafrica' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'New York' is not found !
# An error occurred in the place_parser: the country 'Francia' is not found !
# An error occurred in the place_parser: the country '서울특별시 은평구' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'Sud Africa' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country "Xi'an，Shanxi Province，China" is not found !
# An error occurred in the place_parser: the country 'American Samoa' is not found !
# An error occurred in the place_parser: the country 'Islanda' is not found !
# An error occurred in the place_parser: the country 'Puerto Rico' is not found !
# An error occurred in the place_parser: the country 'Taipei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'Quezon City' is not found !
# An error occurred in the place_parser: the country 'New York City' is not found !
# An error occurred in the place_parser: the country 'Ixelles (Belgique)' is not found !
# An error occurred in the place_parser: the country 'South Korean' is not found !
# An error occurred in the place_parser: the country '神奈川縣厚木市' is not found !
# An error occurred in the place_parser: the country 'Nederland' is not found !
# An error occurred in the place_parser: the country 'Gadarwara' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Ankara' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Phillipines' is not found !
# An error occurred in the place_parser: the country 'Delhi' is not found !
# An error occurred in the place_parser: the country 'Nettuno' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Norvergia' is not found !
# An error occurred in the place_parser: the country "Xi'an，Shanxi Province，China" is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Budel' is not found !
# An error occurred in the place_parser: the country '神奈川縣厚木市' is not found !
# An error occurred in the place_parser: the country 'Bogor' is not found !
# An error occurred in the place_parser: the country 'Luxemburg' is not found !
# An error occurred in the place_parser: the country 'Luxemburg' is not found !
# An error occurred in the place_parser: the country 'U.K.' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'Etiopia' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'American Samoa' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Scotland' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Italia' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Bermuda' is not found !
# An error occurred in the place_parser: the country 'Scotland' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'Budapest' is not found !
# An error occurred in the place_parser: the country 'Budapest' is not found !
# An error occurred in the place_parser: the country 'Corea del Sud' is not found !
# An error occurred in the place_parser: the country 'Napoli' is not found !
# An error occurred in the place_parser: the country 'سوريا' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'California' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Barcelona' is not found !
# An error occurred in the place_parser: the country 'Dendermonde (Belgium)' is not found !
# An error occurred in the place_parser: the country 'Shijiazhuang，Hebei Province，China' is not found !
# An error occurred in the place_parser: the country '中国，北京' is not found !
# An error occurred in the place_parser: the country 'Hangzhou，Zhejiang Province，Chi' is not found !
# An error occurred in the place_parser: the country 'Porto Rico' is not found !
# An error occurred in the place_parser: the country 'Tokyo' is not found !
# An error occurred in the place_parser: the country '中华民国' is not found !
# An error occurred in the place_parser: the country 'Huainan，Anhui Province，China' is not found !
# An error occurred in the place_parser: the country 'California' is not found !
# An error occurred in the place_parser: the country 'Autlán de Navarro (México)' is not found !
# An error occurred in the place_parser: the country 'Barcelona' is not found !
# An error occurred in the place_parser: the country 'Taipei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Jixi，Heilongjiang Province，China' is not found !
# An error occurred in the place_parser: the country 'Taibei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Weifang，Shandong Province，China' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country '中国香港' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'Purchase' is not found !
# An error occurred in the place_parser: the country 'Lussemburgo' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Chengdu，Sichuan Province，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Prayagraj' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Shanghai，China' is not found !
# An error occurred in the place_parser: the country 'Halle (Saale)' is not found !
# An error occurred in the place_parser: the country 'Chongqing，China' is not found !
# An error occurred in the place_parser: the country 'Nanjing，Jiangsu Province，China' is not found !
# An error occurred in the place_parser: the country 'Taibei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country '神奈川縣厚木市' is not found !
# An error occurred in the place_parser: the country 'Shijiazhuang，Hebei Province，China' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Palestine' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country '中国江苏省丹阳市' is not found !
# An error occurred in the place_parser: the country 'Francia' is not found !
# An error occurred in the place_parser: the country 'Yarinacocha District' is not found !
# An error occurred in the place_parser: the country 'Моршанск Тамбовская область' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'Europe' is not found !
# An error occurred in the place_parser: the country '日本大阪府' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Barcelona' is not found !
# An error occurred in the place_parser: the country 'Greenland' is not found !
# An error occurred in the place_parser: the country '서울특별시 강남구' is not found !
# An error occurred in the place_parser: the country 'Besana in Brianza' is not found !
# An error occurred in the place_parser: the country 'Berlin' is not found !
# An error occurred in the place_parser: the country 'Quezon City' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Jakarta' is not found !
# An error occurred in the place_parser: the country 'Quezon City' is not found !
# An error occurred in the place_parser: the country 'Argentine' is not found !
# An error occurred in the place_parser: the country 'Karaków Poland' is not found !
# An error occurred in the place_parser: the country 'jiayi，taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Phillipines' is not found !
# An error occurred in the place_parser: the country 'الكويت' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Cotabato' is not found !
# An error occurred in the place_parser: the country 'Aceh' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country '神奈川縣厚木市' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Tunis' is not found !
# An error occurred in the place_parser: the country 'Bursa' is not found !
# An error occurred in the place_parser: the country '神奈川縣厚木市' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Egyptian' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Sukabumi' is not found !
# An error occurred in the place_parser: the country "Qiqiha'er，Heilongjiang Province" is not found !
# An error occurred in the place_parser: the country 'Wonosobo' is not found !
# An error occurred in the place_parser: the country 'Bogor' is not found !
# An error occurred in the place_parser: the country 'Mysore' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Bursa' is not found !
# An error occurred in the place_parser: the country 'Magelang' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country '北京，中国' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Paris' is not found !
# An error occurred in the place_parser: the country 'Pingdingshan，He‘nan Province，China' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Shenyang，Liaoning Province，China' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Weihai，Shandong Province，China' is not found !
# An error occurred in the place_parser: the country '中国，河南' is not found !
# An error occurred in the place_parser: the country '中国北京' is not found !
# An error occurred in the place_parser: the country '中华人民共和国北京市' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Dendermonde (Belgium)' is not found !
# An error occurred in the place_parser: the country 'Rhodesia [now Zimbabwe]' is not found !
# An error occurred in the place_parser: the country 'California' is not found !
# An error occurred in the place_parser: the country 'Sydney' is not found !
# An error occurred in the place_parser: the country 'Gran Bretagna' is not found !
# An error occurred in the place_parser: the country 'South Vietnam' is not found !
# An error occurred in the place_parser: the country 'Corea del Sud' is not found !
# An error occurred in the place_parser: the country 'Haikou，Hainan Province，China' is not found !
# An error occurred in the place_parser: the country '中國湖南省' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Brasil' is not found !
# An error occurred in the place_parser: the country 'bharatpur rajasthan' is not found !
# An error occurred in the place_parser: the country 'Regno Unito' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Filippine' is not found !
# An error occurred in the place_parser: the country 'Illinois' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Republic of Ireland' is not found !
# An error occurred in the place_parser: the country 'Moçambique' is not found !
# An error occurred in the place_parser: the country '宣城，安徽，中国' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'Autlán de Navarro (México)' is not found !
# An error occurred in the place_parser: the country 'Moscow' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country "Ha'er‘bing，Heilongjiang Province，China" is not found !
# An error occurred in the place_parser: the country 'Taibei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Napoli' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Barcelona' is not found !
# An error occurred in the place_parser: the country 'Leipzig' is not found !
# An error occurred in the place_parser: the country 'West Indies' is not found !
# An error occurred in the place_parser: the country 'Mexico DF' is not found !
# An error occurred in the place_parser: the country 'Nettuno' is not found !
# An error occurred in the place_parser: the country 'Napoli' is not found !
# An error occurred in the place_parser: the country 'Corea del Sud' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'USSR' is not found !
# An error occurred in the place_parser: the country 'The Netherlands' is not found !
# An error occurred in the place_parser: the country '台湾台北' is not found !
# An error occurred in the place_parser: the country 'Milano' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Salerno' is not found !
# An error occurred in the place_parser: the country 'Detroit' is not found !
# An error occurred in the place_parser: the country 'Tokyo' is not found !
# An error occurred in the place_parser: the country 'Jiaxing，Zhejiang Province，China' is not found !
# An error occurred in the place_parser: the country 'Zigong，Sichuan Province，China' is not found !
# An error occurred in the place_parser: the country 'Jiaxing，Zhejiang Province，China' is not found !
# An error occurred in the place_parser: the country 'xizang，China' is not found !
# An error occurred in the place_parser: the country 'Etiopia' is not found !
# An error occurred in the place_parser: the country 'Europe' is not found !
# An error occurred in the place_parser: the country 'Porto Rico' is not found !
# An error occurred in the place_parser: the country 'Shanghai，China' is not found !
# An error occurred in the place_parser: the country 'Maharashtra' is not found !
# An error occurred in the place_parser: the country 'Delhi' is not found !
# An error occurred in the place_parser: the country 'Prayagraj' is not found !
# An error occurred in the place_parser: the country 'Varese' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Paris France' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Buenos Aires' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Maharashtra' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hangzhou，Zhejiang Province，Chi' is not found !
# An error occurred in the place_parser: the country 'Shenzhen，Guangdong Province，China' is not found !
# An error occurred in the place_parser: the country 'Changsha，Hunan Province，China' is not found !
# An error occurred in the place_parser: the country 'Huainan，Anhui Province，China' is not found !
# An error occurred in the place_parser: the country '美国纽约州纽约市布鲁克林区科尼岛（Coney Island， Brooklyn， New York City，New York）' is not found !
# An error occurred in the place_parser: the country 'INDIA' is not found !
# An error occurred in the place_parser: the country 'Milano' is not found !
# An error occurred in the place_parser: the country 'Laudio/Llodio' is not found !
# An error occurred in the place_parser: the country 'Hongkong，China' is not found !
# An error occurred in the place_parser: the country 'Changsha，Hunan Province，China' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'Trinidad' is not found !
# An error occurred in the place_parser: the country 'South Korean' is not found !
# An error occurred in the place_parser: the country 'Taipei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'taizhong，taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Dongtai Jiangsu China' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country '日本/北海道' is not found !
# An error occurred in the place_parser: the country 'Napoli' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Taipei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Chengdu，Sichuan Province，China' is not found !
# An error occurred in the place_parser: the country 'Shanghai，China' is not found !
# An error occurred in the place_parser: the country 'zigong，sichuan，China' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Makassar' is not found !
# An error occurred in the place_parser: the country 'Jilin，Jilin Province，China' is not found !
# An error occurred in the place_parser: the country "Xi'an，Shanxi Province，China" is not found !
# An error occurred in the place_parser: the country 'Heusden' is not found !
# An error occurred in the place_parser: the country 'Kessel' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Pattambi' is not found !
# An error occurred in the place_parser: the country 'Phillipines' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'Taibei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Quezon City' is not found !
# An error occurred in the place_parser: the country 'Filippine' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country '中国四川' is not found !
# An error occurred in the place_parser: the country 'INDIA' is not found !
# An error occurred in the place_parser: the country 'الكويت' is not found !
# An error occurred in the place_parser: the country 'Sukabumi' is not found !
# An error occurred in the place_parser: the country 'تونس' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Almanya' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'Sukabumi' is not found !
# An error occurred in the place_parser: the country 'Shijiazhuang，Hebei Province，China' is not found !
# An error occurred in the place_parser: the country 'Hongkong，China' is not found !
# An error occurred in the place_parser: the country 'Thohoyandou' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'British India' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Tokyo' is not found !
# An error occurred in the place_parser: the country 'Mamidipalli' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Faridpur District' is not found !
# An error occurred in the place_parser: the country 'XinZhu，Taiwan' is not found !
# An error occurred in the place_parser: the country 'taizhong，taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Qingdao，Shandong Province，China' is not found !
# An error occurred in the place_parser: the country 'Hongkong，China' is not found !
# An error occurred in the place_parser: the country 'Francia' is not found !
# An error occurred in the place_parser: the country 'Maumere' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Bogor' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Magelang' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Phillipines' is not found !
# An error occurred in the place_parser: the country 'Riotorto (Lugo)' is not found !
# An error occurred in the place_parser: the country 'New York' is not found !
# An error occurred in the place_parser: the country 'Texas' is not found !
# An error occurred in the place_parser: the country 'Napoli' is not found !
# An error occurred in the place_parser: the country 'Taranto' is not found !
# An error occurred in the place_parser: the country 'Napoli' is not found !
# An error occurred in the place_parser: the country 'Napoli' is not found !
# An error occurred in the place_parser: the country 'Leipzig' is not found !
# An error occurred in the place_parser: the country 'Republic of Cyprus' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Korea' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Nuova Zelanda' is not found !
# An error occurred in the place_parser: the country 'Danmark' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Poniewież na Litwie' is not found !
# An error occurred in the place_parser: the country 'Copenhagen' is not found !
# An error occurred in the place_parser: the country 'Danimarca' is not found !
# An error occurred in the place_parser: the country 'Barcelona' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'Italia' is not found !
# An error occurred in the place_parser: the country 'Regno Unito' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Danimarca' is not found !
# An error occurred in the place_parser: the country 'Etiopia' is not found !
# An error occurred in the place_parser: the country 'Great Britain' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Etiopia' is not found !
# An error occurred in the place_parser: the country 'Ostrava' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Luxemburg' is not found !
# An error occurred in the place_parser: the country 'England' is not found !
# An error occurred in the place_parser: the country 'Shenzhen，Guangdong Province，China' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country '中国' is not found !
# An error occurred in the place_parser: the country 'Ohio' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Corea del Sud' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Weifang，Shandong Province，China' is not found !
# An error occurred in the place_parser: the country 'Zhengzhou，Henan Province，China' is not found !
# An error occurred in the place_parser: the country 'Seoul South Korea' is not found !
# An error occurred in the place_parser: the country 'The Hague' is not found !
# An error occurred in the place_parser: the country 'Bogor' is not found !
# An error occurred in the place_parser: the country 'Salerno' is not found !
# An error occurred in the place_parser: the country 'Salerno' is not found !
# An error occurred in the place_parser: the country 'The Netherlands' is not found !
# An error occurred in the place_parser: the country 'The Netherlands' is not found !
# An error occurred in the place_parser: the country 'Gadarwara' is not found !
# An error occurred in the place_parser: the country 'Milano (Italy)' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'UK' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Napoli' is not found !
# An error occurred in the place_parser: the country '台湾台北' is not found !
# An error occurred in the place_parser: the country 'Milano' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Scotland' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Maharashtra' is not found !
# An error occurred in the place_parser: the country "Ha'er‘bing，Heilongjiang Province，China" is not found !
# An error occurred in the place_parser: the country "Ha'er‘bing，Heilongjiang Province，China" is not found !
# An error occurred in the place_parser: the country '中国，北京' is not found !
# An error occurred in the place_parser: the country 'Beijing，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Chongqing，China' is not found !
# An error occurred in the place_parser: the country 'Xianning，Hubei Province，China' is not found !
# An error occurred in the place_parser: the country 'Qingdao，Shandong Province，China' is not found !
# An error occurred in the place_parser: the country 'Anshan，Liaoning Province，China' is not found !
# An error occurred in the place_parser: the country 'Jiangmen，Guangdong Province，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country '日本/北海道' is not found !
# An error occurred in the place_parser: the country 'Wuhan，Hubei Province，China' is not found !
# An error occurred in the place_parser: the country 'Mudanjiang，Heilongjiang Province，China' is not found !
# An error occurred in the place_parser: the country 'Suzhou，Jiangsu Province，China' is not found !
# An error occurred in the place_parser: the country 'Tianjin，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Ivory Coast' is not found !
# An error occurred in the place_parser: the country 'Nedumangad' is not found !
# An error occurred in the place_parser: the country 'Chongqing，China' is not found !
# An error occurred in the place_parser: the country 'Chifeng，Inner Mongolia，China' is not found !
# An error occurred in the place_parser: the country '泰国' is not found !
# An error occurred in the place_parser: the country 'Roma' is not found !
# An error occurred in the place_parser: the country 'Garbagnate Milanese' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Brasil' is not found !
# An error occurred in the place_parser: the country 'لبنان' is not found !
# An error occurred in the place_parser: the country 'Kattenberg' is not found !
# An error occurred in the place_parser: the country 'Verona' is not found !
# An error occurred in the place_parser: the country 'Taranto' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'الكويت' is not found !
# An error occurred in the place_parser: the country 'تونس' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Polska' is not found !
# An error occurred in the place_parser: the country 'Polska' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country '中国' is not found !
# An error occurred in the place_parser: the country '中国' is not found !
# An error occurred in the place_parser: the country 'Québec' is not found !
# An error occurred in the place_parser: the country 'Shenyang，Liaoning Province，China' is not found !
# An error occurred in the place_parser: the country 'Qingdao，Shandong，China' is not found !
# An error occurred in the place_parser: the country 'Suzhou，Jiangsu Province，China' is not found !
# An error occurred in the place_parser: the country 'Nador' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Gadarwara' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'British Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'Biên Hòa' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'Garbagnate Milanese' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Jakarta' is not found !
# An error occurred in the place_parser: the country 'Sukabumi' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country 'Taibei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'Hong Kong' is not found !
# An error occurred in the place_parser: the country 'Taibei，Taiwan，China' is not found !
# An error occurred in the place_parser: the country 'London' is not found !
# An error occurred in the place_parser: the country '中国河南三门峡' is not found !
# An error occurred in the place_parser: the country 'Tonghua，Jilin Province，China' is not found !
# An error occurred in the place_parser: the country 'Nanjing，Jiangsu Province，China' is not found !
# An error occurred in the place_parser: the country 'Jakarta' is not found !
# An error occurred in the place_parser: the country 'مصر' is not found !
# An error occurred in the place_parser: the country 'Wonosobo' is not found !
# An error occurred in the place_parser: the country 'Bogor' is not found !
# An error occurred in the place_parser: the country 'Aceh' is not found !
# An error occurred in the place_parser: the country 'Thohoyandou' is not found !

# %%
df = pd.read_csv('../data/new_credits.csv')
df
# Out:
#        Unnamed: 0  person_id         id                name  \
# 0               0       3748    tm84618      Robert De Niro
# 1               1      14658    tm84618        Jodie Foster
# 2               2       7064    tm84618       Albert Brooks
# 3               3       3739    tm84618       Harvey Keitel
# 4               4      48933    tm84618     Cybill Shepherd
# ...           ...        ...        ...                 ...
# 77796       77796     736339  tm1059008    Adelaida Buscato
# 77797       77797     399499  tm1059008  Luz Stella Luengas
# 77798       77798     373198  tm1059008         Inés Prieto
# 77799       77799     378132  tm1059008        Isabel Gaona
# 77800       77800    1950416  tm1059008      Julian Gaviria
#
#                      character      role           city       state  \
# 0                Travis Bickle     ACTOR  New York City    New York
# 1                Iris Steensma     ACTOR    Los Angeles  California
# 2                          Tom     ACTOR  Beverly Hills  California
# 3      Matthew 'Sport' Higgins     ACTOR  New York City    New York
# 4                        Betsy     ACTOR        Memphis   Tennessee
# ...                        ...       ...            ...         ...
# 77796                María Paz     ACTOR            NaN         NaN
# 77797             Karen Bayona     ACTOR       Medellin   Antioquia
# 77798                    Fanny     ACTOR            NaN         NaN
# 77799                   Cacica     ACTOR            NaN         NaN
# 77800                      NaN  DIRECTOR            NaN         NaN
#
#              country  iso                     latlong
# 0      United States   US   (40.7127281, -74.0060152)
# 1      United States   US   (34.0536909, -118.242766)
# 2      United States   US  (34.0696501, -118.3963062)
# 3      United States   US   (40.7127281, -74.0060152)
# 4      United States   US   (35.1335022, -89.9668758)
# ...              ...  ...                         ...
# 77796            NaN  NaN                         NaN
# 77797       Colombia   CO     (6.2443382, -75.573553)
# 77798            NaN  NaN                         NaN
# 77799            NaN  NaN                         NaN
# 77800            NaN  NaN                         NaN
#
# [77801 rows x 11 columns]
